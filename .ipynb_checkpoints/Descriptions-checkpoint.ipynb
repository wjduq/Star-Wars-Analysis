# %%
import pandas as pd

descriptionsDf = pd.read_csv("starwars_descriptions.csv")

descriptionsDf.set_index(["name"], inplace = True)

descriptionsDf.drop(["vehicles", "starships", "homeworld"], axis = 1)
# Out:
#                 height   mass hair_color   skin_color eye_color  birth_year  \
# name
# Luke Skywalker   172.0   77.0      blond         fair      blue        19.0
# C-3PO            167.0   75.0        NaN         gold    yellow       112.0
# R2-D2             96.0   32.0        NaN  white, blue       red        33.0
# Darth Vader      202.0  136.0       none        white    yellow        41.9
# Leia Organa      150.0   49.0      brown        light     brown        19.0
# ...                ...    ...        ...          ...       ...         ...
# Rey                NaN    NaN      brown        light     hazel         NaN
# Poe Dameron        NaN    NaN      brown        light     brown         NaN
# BB8                NaN    NaN       none         none     black         NaN
# Captain Phasma     NaN    NaN    unknown      unknown   unknown         NaN
# Padmé Amidala    165.0   45.0      brown        light     brown        46.0
#
#                    sex     gender species  \
# name
# Luke Skywalker    male  masculine   Human
# C-3PO             none  masculine   Droid
# R2-D2             none  masculine   Droid
# Darth Vader       male  masculine   Human
# Leia Organa     female   feminine   Human
# ...                ...        ...     ...
# Rey             female   feminine   Human
# Poe Dameron       male  masculine   Human
# BB8               none  masculine   Droid
# Captain Phasma     NaN        NaN     NaN
# Padmé Amidala   female   feminine   Human
#
#                                                             films
# name
# Luke Skywalker  The Empire Strikes Back, Revenge of the Sith, ...
# C-3PO           The Empire Strikes Back, Attack of the Clones,...
# R2-D2           The Empire Strikes Back, Attack of the Clones,...
# Darth Vader     The Empire Strikes Back, Revenge of the Sith, ...
# Leia Organa     The Empire Strikes Back, Revenge of the Sith, ...
# ...                                                           ...
# Rey                                             The Force Awakens
# Poe Dameron                                     The Force Awakens
# BB8                                             The Force Awakens
# Captain Phasma                                  The Force Awakens
# Padmé Amidala   Attack of the Clones, The Phantom Menace, Reve...
#
# [87 rows x 10 columns]
